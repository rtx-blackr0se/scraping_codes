# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time

# %%
# for PART 1
# make a list of numbers from 023200 to 024763

numbers = list(range(22499, 23200))

str_numbers = list(map(str, numbers))

DUAs = []

for str_number in str_numbers:
    DUAs.append('0' + str_number)

Administracion_de_Aduana = []
Nro_de_envio = []
Regimen = []
Modalidad = []
Fecha_de_Registro= []
Tipo_de_DUA= []
Numero_del_DUA= []
Forma_de_despacho= []
Tipo_semaforo = []
Estado= []
Importador_Exportador_Remitente= []
Declarante= []
Importe_Total_Facturas= []
Total_CIF= []
Total_Peso_Bruto= []
Neto = []
Medio_de_Transporte = []
Empresa_Transportista= []
Aduana_de_Ingreso_Salida = []
Lugar_de_Localizacion= []
Aduana_Destino= []
Lugar_de_Destino= []
Total_a_garantizar= []
Nro_Garantia= []
Tipo_cambio= []
Observaciones= []

# FOR Part 2:
Partida = []
Descripcion_Comercial = []
Bultos = []
Tipo_de_Bulto = []
Marcas = []
CIF_USD = []
Peso_Bruto = []
Peso_Neto = []
Matricula_Nave = []
Nombre_Nave = []
Conoc_Embarque = []
Manifesto = []
Linea_Ing = []
Fecha_Arribo = []

#Making a list of strings from 01 to 99

integers = list(range(10, 100))

strings = []
for integer in integers:
    strings.append(str(integer))

numbers = ['01', '02', '03', '04', '05', '06', '07', '08', '09'] + strings

loading = 0

for DUA in DUAs:
    
    try:
        driver = webdriver.Chrome(ChromeDriverManager().install())
        driver.get('https://www.hacienda.go.cr/tica/web/hcnduaap.aspx')
        select = Select(driver.find_element_by_name('vVCODI_ADUA'))
        select.select_by_visible_text('Limón')
        DUA_number = driver.find_element_by_name('vVNUME_CORR')
    
    # Input the DUA in the form
        DUA_number.send_keys(DUA)
    
   # Open that DUA
        

    # freeze the code for a bit to let the website load
        time.sleep(4)
    
    except:
        pass
    
    #loading screen
    loading = loading + 1
    print('Working on DUA', loading, 'out of', len(DUAs), ".")
    
    cosmos = driver.find_elements_by_class_name('ReadonlyAttribute')
    
    try:
        Administracion_de_Aduana.append(cosmos[1].text + "-" + cosmos[2].text)
    except:
        Administracion_de_Aduana.append('Null.')
        
    try:
        Nro_de_envio.append(cosmos[3].text)
    except:
        Nro_de_envio.append('Null.')
        
    try:
        Regimen.append(cosmos[4].text + "-" + cosmos[5].text)
    except:
        Regimen.append('Null.')
        
    try:
        Modalidad.append(cosmos[6].text + "-" + cosmos[7].text)
    except:
        Modalidad.append('Null.')
        
    try:
        Fecha_de_Registro.append(cosmos[8].text + "-" + cosmos[9].text)
    except:
        Fecha_de_Registro.append('Null.')
        
    try:
        Tipo_de_DUA.append(cosmos[10].text)
    except:
        Tipo_de_DUA.append('Null.')
        
    try:
        Numero_del_DUA.append(cosmos[11].text + " " + cosmos[12].text + " " + cosmos[13].text)
    except:
        Numero_del_DUA.append('Null.')
        
    try:
        Forma_de_despacho.append(cosmos[14].text + "-" + cosmos[15].text)
    except:
        Forma_de_despacho.append('Null.')
        
    try:
        Tipo_semaforo.append(cosmos[16].text + "-" + cosmos[17].text)
    except:
        Tipo_semaforo.append('Null.')
        
    try:
        Estado.append(cosmos[18].text + cosmos[19].text)
    except:
        Estado.append('Null.')
        
    try:
        Importador_Exportador_Remitente.append(cosmos[20].text + "-" + cosmos[21].text)
    except:
        Importador_Exportador_Remitente.append('Null.')
        
    try:
        Declarante.append(cosmos[22].text + "-" + cosmos[23].text + " " + cosmos[24].text)
    except:
        Declarante.append('Null.')
        
    try:
        Importe_Total_Facturas.append(cosmos[25].text + " " + cosmos[26].text + " " +cosmos[27].text)
    except:
        Importe_Total_Facturas.append('Null.')
        
    try:
        Total_CIF.append(cosmos[28].text)
    except:
        Total_CIF.append('Null.')
        
    try:
        Total_Peso_Bruto.append(cosmos[29].text)
    except:
        Total_Peso_Bruto.append('Null.')
        
    try:
        Neto.append(cosmos[30].text)
    except:
        Neto.append('Null.')
        
    try:
        Medio_de_Transporte.append(cosmos[31].text)
    except:
        Medio_de_Transporte.append('Null.')
        
    try:
        Empresa_Transportista.append(cosmos[32].text + cosmos[33].text)
    except:
        Empresa_Transportista.append('Null.')
        
    try:
        Aduana_de_Ingreso_Salida.append(cosmos[34].text + " " +cosmos[35].text)
    except:
        Aduana_de_Ingreso_Salida.append('Null.')
        
    try:
        Lugar_de_Localizacion.append(cosmos[36].text + " " +cosmos[37].text)
    except:
        Lugar_de_Localizacion.append('Null.')
    
    try:
        Aduana_Destino.append(cosmos[38].text + " " +cosmos[39].text)
    except:
        Aduana_Destino.append('Null.')
        
    try:
        Lugar_de_Destino.append(cosmos[40].text + " " +cosmos[41].text)
    except:
        Lugar_de_Destino.append('Null.')
        
    try:
        Total_a_garantizar.append(cosmos[42].text)
    except:
        Total_a_garantizar.append('Null.')
        
    try:
        Nro_Garantia.append(cosmos[43].text)
    except:
        Nro_Garantia.append('Null.')
        
    try:
        Tipo_cambio.append(cosmos[44].text)
    except:
        Tipo_cambio.append('Null.')
        
    try:
        Observaciones.append(cosmos[45].text)
    except:
        Observaciones.append('Null.')
        
        

    # PART 2
    for number in numbers:

        try:
            Partida.append(driver.find_element_by_id('span_PARTIDA_00' + number).text)
        except:
            pass

        try:
            Descripcion_Comercial.append(driver.find_element_by_id('span_DESC_COMER_00' + number).text)
        except:
            pass
        try:
            Bultos.append(driver.find_element_by_id('span_vVCANTBULTO_00' + number).text)
        except:
            pass
        try:
            Tipo_de_Bulto.append(driver.find_element_by_id('span_vVTIPBDSC_00' + number).text)
        except:
            pass
        try:
            Marcas.append(driver.find_element_by_id('span_MARCAS_NUM_00' + number).text)
        except:
            pass
        try:
            CIF_USD.append(driver.find_element_by_id('span_CIF_DOLPOL_00' + number).text)
        except:
            pass
        try:
            Peso_Bruto.append(driver.find_element_by_id('span_PESO_BRUTO_00' + number).text)
        except:
            pass
        try:
            Peso_Neto.append(driver.find_element_by_id('span_PESO_NETO_00' + number).text)
        except:
            pass
        try:
            Matricula_Nave.append(driver.find_element_by_id('span_vCGMATNAVE_00' + number).text)
        except:
            pass
        try:
            Nombre_Nave.append(driver.find_element_by_id('span_vCGNOMNAVE_00' + number).text)
        except:
            pass
        try:
            Conoc_Embarque.append(driver.find_element_by_id('span_vCGNROCON_00' + number).text)
        except:
            pass
        try:
            Manifesto.append(driver.find_element_by_id('span_vCGNROMIC_00' + number).text)
        except:
            pass
        try:
            Linea_Ing.append(driver.find_element_by_id('span_vCGNROLIN_00' + number).text)
        except:
            pass
        try:
            Fecha_Arribo.append(driver.find_element_by_id('span_vCGFCHARR_00' + number).text)
        except:
            pass
# Out:
# Trying to download new driver from http://chromedriver.storage.googleapis.com/91.0.4472.101/chromedriver_win32.zip
# Unpack archive C:\Users\Shaleen\.wdm\drivers\chromedriver\91.0.4472.101\win32\chromedriver.zip
# Working on DUA 1 out of 701 .
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-409e076b8cc0> in <module>
#      91     print('Working on DUA', loading, 'out of', len(DUAs), ".")
#      92
# ---> 93     cosmos = driver.find_elements_by_class_name('ReadonlyAttribute')
#      94
#      95     try:
#
# NameError: name 'driver' is not defined

# %%
# Part 1 result:

zippedlist = list(zip(DUAs, Administracion_de_Aduana,
Nro_de_envio,
Regimen,
Modalidad,
Fecha_de_Registro,
Tipo_de_DUA,
Numero_del_DUA,
Forma_de_despacho,
Tipo_semaforo, 
Estado,
Importador_Exportador_Remitente,
Declarante,
Importe_Total_Facturas,
Total_CIF,
Total_Peso_Bruto,
Neto,
Medio_de_Transporte,
Empresa_Transportista,
Aduana_de_Ingreso_Salida ,
Lugar_de_Localizacion,
Aduana_Destino,
Lugar_de_Destino,
Total_a_garantizar,
Nro_Garantia,
Tipo_cambio,
Observaciones,
))

df = pd.DataFrame(zippedlist, columns = ['DUAs', 'Administracion_de_Aduana',
'Nro_de_envio',
'Regimen',
'Modalidad',
'Fecha_de_Registro',
'Tipo_de_DUA',
'Numero_del_DUA',
'Forma_de_despacho',
'Tipo_semaforo', 
'Estado',
'Importador_Exportador_Remitente',
'Declarante',
'Importe_Total_Facturas',
'Total_CIF',
'Total_Peso_Bruto',
'Neto',
'Medio_de_Transporte',
'Empresa_Transportista',
'Aduana_de_Ingreso_Salida',
'Lugar_de_Localizacion',
'Aduana_Destino',
'Lugar_de_Destino',
'Total_a_garantizar',
'Nro_Garantia',
'Tipo_cambio',
'Observaciones'])

df.to_csv('DUAs_scraped_Part1_022499_023200.csv')

# %%
# Part 2 result:
Item = list(range(1,len(Marcas)+1))

zippedlist2 = list(zip(DUAs, Item, Partida, Descripcion_Comercial, Bultos, Tipo_de_Bulto, Marcas, CIF_USD, Peso_Bruto, Peso_Neto, Matricula_Nave, Nombre_Nave, Conoc_Embarque, Manifesto, Linea_Ing, Fecha_Arribo))

df2 = pd.DataFrame(zippedlist2, columns = ['DUAs', 'Item', 'Partida', 'Descripcion_Comercial', 'Bultos', 'Tipo_de_Bulto', 'Marcas', 'CIF_USD', 'Peso_Bruto', 'Peso_Neto', 'Matricula_Nave', 'Nombre_Nave', 'Conoc_Embarque', 'Manifesto', 'Linea_Ing', 'Fecha_Arribo'])

df2.to_csv('DUAs_scraped_Part2_022499_023200.csv')
